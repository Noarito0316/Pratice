# %% [markdown]
# <a href="https://colab.research.google.com/github/Noarito0316/Pratice/blob/main/Trabalho_de_cartas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

baralho = [
    #Paus
    {"carta": "ás", "naipe": "paus", "valor": 1.1},
    {"carta": "2", "naipe": "paus", "valor": 2.1},
    {"carta": "3", "naipe": "paus", "valor": 3.1},
    {"carta": "4", "naipe": "paus", "valor": 4.1},
    {"carta": "5", "naipe": "paus", "valor": 5.1},
    {"carta": "6", "naipe": "paus", "valor": 6.1},
    {"carta": "7", "naipe": "paus", "valor": 7.1},
    {"carta": "8", "naipe": "paus", "valor": 8.1},
    {"carta": "9", "naipe": "paus", "valor": 9.1},
    {"carta": "10", "naipe": "paus", "valor": 10.1},
    {"carta": "valete", "naipe": "paus", "valor": 11.1},
    {"carta": "dama", "naipe": "paus", "valor": 12.1},
    {"carta": "rei", "naipe": "paus", "valor": 13.1},
    #Ouros
    {"carta": "ás", "naipe": "ouros", "valor": 1.2},
    {"carta": "2", "naipe": "ouros", "valor": 2.2},
    {"carta": "3", "naipe": "ouros", "valor": 3.2},
    {"carta": "4", "naipe": "ouros", "valor": 4.2},
    {"carta": "5", "naipe": "ouros", "valor": 5.2},
    {"carta": "6", "naipe": "ouros", "valor": 6.2},
    {"carta": "7", "naipe": "ouros", "valor": 7.2},
    {"carta": "8", "naipe": "ouros", "valor": 8.2},
    {"carta": "9", "naipe": "ouros", "valor": 9.2},
    {"carta": "10", "naipe": "ouros", "valor": 10.2},
    {"carta": "valete", "naipe": "ouros", "valor": 11.2},
    {"carta": "dama", "naipe": "ouros", "valor": 12.2},
    {"carta": "rei", "naipe": "ouros", "valor": 13.2},
    #Copas
    {"carta": "ás", "naipe": "copas", "valor": 1.3},
    {"carta": "2", "naipe": "copas", "valor": 2.3},
    {"carta": "3", "naipe": "copas", "valor": 3.3},
    {"carta": "4", "naipe": "copas", "valor": 4.3},
    {"carta": "5", "naipe": "copas", "valor": 5.3},
    {"carta": "6", "naipe": "copas", "valor": 6.3},
    {"carta": "7", "naipe": "copas", "valor": 7.3},
    {"carta": "8", "naipe": "copas", "valor": 8.3},
    {"carta": "9", "naipe": "copas", "valor": 9.3},
    {"carta": "10", "naipe": "copas", "valor": 10.3},
    {"carta": "valete", "naipe": "copas", "valor": 11.3},
    {"carta": "dama", "naipe": "copas", "valor": 12.3},
    {"carta": "rei", "naipe": "copas", "valor": 13.3},
    #Espadas
    {"carta": "ás", "naipe": "espadas", "valor": 1.4},
    {"carta": "2", "naipe": "espadas", "valor": 2.4},
    {"carta": "3", "naipe": "espadas", "valor": 3.4},
    {"carta": "4", "naipe": "espadas", "valor": 4.4},
    {"carta": "5", "naipe": "espadas", "valor": 5.4},
    {"carta": "6", "naipe": "espadas", "valor": 6.4},
    {"carta": "7", "naipe": "espadas", "valor": 7.4},
    {"carta": "8", "naipe": "espadas", "valor": 8.4},
    {"carta": "9", "naipe": "espadas", "valor": 9.4},
    {"carta": "10", "naipe": "espadas", "valor": 10.4},
    {"carta": "valete", "naipe": "espadas", "valor": 11.4},
    {"carta": "dama", "naipe": "espadas", "valor": 12.4},
    {"carta": "rei", "naipe": "espadas", "valor": 13.4}
]

def verificação_maior_ou_menor(x,y,valor_de_i,validação_maior_menor):
    print(f' {valor_de_i+1}° carta vale {x} e {valor_de_i+2}° carta vale {y}')
    if validação_maior_menor == "maior" and x > y:
      return True
    if validação_maior_menor == "menor" and x < y:
      return True
    else:
      return False


pontos = 0
maior_ou_menor = ''
carta_principal = []
random.shuffle(baralho)
for i in range(8):
  carta_principal.append(baralho.pop(0))
for i in range(7):
  print(f'A {i+1}° carta é: {carta_principal[i]["carta"]} de {carta_principal[i]["naipe"]} ')
  print('A proxima carta é maior ou menor?')
  maior_ou_menor = input("('maior' para maior ou 'menor' para menor)")
  print(f'A {i+2}° carta é: {carta_principal[i+1]["carta"]} de {carta_principal[i+1]["naipe"]} ')
  if verificação_maior_ou_menor(carta_principal[i]["valor"],carta_principal[i+1]["valor"],i,maior_ou_menor):
    pontos += 200
    print('Acertou!')
  else:
    pontos -= 150
    print('Errou')
print(f'Você fez um total de {pontos} pontos!')
# Out:
# A 1° carta é: ás de espadas
# A proxima carta é maior ou menor?
# ('maior' para maior ou 'menor' para menor)maior
# A 2° carta é: dama de paus
#  1° carta vale 1.4 e 2° carta vale 12.1
# Errou
# A 2° carta é: dama de paus
# A proxima carta é maior ou menor?
# ('maior' para maior ou 'menor' para menor)maior
# A 3° carta é: 7 de ouros
#  2° carta vale 12.1 e 3° carta vale 7.2
# Acertou!
# A 3° carta é: 7 de ouros
# A proxima carta é maior ou menor?
# ('maior' para maior ou 'menor' para menor)maior
# A 4° carta é: 2 de paus
#  3° carta vale 7.2 e 4° carta vale 2.1
# Acertou!
# A 4° carta é: 2 de paus
# A proxima carta é maior ou menor?
# ('maior' para maior ou 'menor' para menor)maior
# A 5° carta é: dama de ouros
#  4° carta vale 2.1 e 5° carta vale 12.2
# Errou
# A 5° carta é: dama de ouros
# A proxima carta é maior ou menor?
# ('maior' para maior ou 'menor' para menor)maior
# A 6° carta é: 3 de paus
#  5° carta vale 12.2 e 6° carta vale 3.1
# Acertou!
# A 6° carta é: 3 de paus
# ...
